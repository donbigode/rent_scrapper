# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import csv

URL = "https://www.vivareal.com.br/aluguel/sp/sao-jose-dos-campos/apartamento_residencial/?gclid=Cj0KCQjwlOmLBhCHARIsAGiJg7k_AHQCJ7G4c_0e05-qjNTwR3cHP5yNBI18ZfHbmOLZKoqoJGjZAsYaAutxEALw_wcB&utm_referrer=https%3A%2F%2Fwww.google.com%2F"
r = requests.get(URL)
conteudo = r.text

test = []

soup = BeautifulSoup(conteudo, "html.parser")

raw = soup.findAll('p')
raw2 = soup.findAll('a')

for row in range(len(raw2)):
    test.append(raw2[row].text).findAll('p')



print(len(raw2))
print(test)


#page = pd.read_json(raw.split(">"))
# Out:
# 214
# ...
